# %% [markdown]
# <a href="https://colab.research.google.com/github/Nova1323/Machine-Learning/blob/master/CNN/Cats%20Vs%20Dogs/Cats%20Vs%20Dogs%20(With%20Image%20Augmentation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cats Vs Dogs (With Image Augmentation)
#
# Part 2 of the Image Classifier which classifies cats and dogs

# %% [markdown]
# ### Importing Libraries
#
# Libraries used for this exercise are:
# 1. os for creating directories and folders
# 2. zipfile for extracting the data from the zip file
# 3. numpy for creating and modifing arrays
# 4. pandas for dataframes
# 4. matplotlib for ploting and visualizing the data
# 5. tensorflow for implementing the CNN

# %%
import os
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Loading the Data
#
# You can download the data by running this script

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
    -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2020-07-21 10:03:31--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.79.128, 108.177.126.128, 108.177.127.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.79.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M  98.0MB/s    in 0.7s
#
# 2020-07-21 10:03:32 (98.0 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %% [markdown]
# The file is then unziped and seperated into different folders which contain the photos for our problem.
#
# Tensorflow's Image Generator will name the data according to the folder names.
#
# For eg: we have our dataset split into parts test and validation and each folder contains two sub-folder namely cats and dogs. All the images that are in the `'/training/cats/'` folder will be considered as the training data for cats while `'/training/dogs/'` folder will be considered as the training data for dogs.

# %%
local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/cats_and_dogs_filtered'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat pictures
train_cats_dir = os.path.join(train_dir, 'cats')

# Directory with our training dog pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')

# Directory with our validation dog pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# ### Creating the Neural Network

# %% [markdown]
# The model will first take an image and try multiple convolutions on it using the `Conv2D` layer.
#
# A (3,3) convolution multiples the pixels of the image by a 3 by 3 matrix. This matrix consists of values according to which certainfeatures of the image are highlighted or removed. This works much like applying a filter on the image.
# An image of 150 by 150 pixles when passed through a 3 by 3 convolution gets reduced to a 148 by 148 pixel image as the filter cannot be applies to the sides of the image as the don't have all the neighbouring pixels.
#
# The image is then passed through a `MaxPooling2D` layer. If an input of (2,2) is given then the layer keeps the largest value of the 4 neighbouring pixles and deletes the rest. Thus reducing the amount of information that is needed to be processed making our Network run faster
#
# The Image is the flattened and passed through the Dense layer. (More information on these layers and activations is given in the Fashoin MNIST problem)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# By calling the summary method we can see how the data is tranformed as it passes through the model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We then compile the model.
#
# Here we use the `binary_crossentropy` loss function as there are only two outputs.

# %%
model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(lr=1e-4),
              metrics=['accuracy'])

# %% [markdown]
# ### Image Generators
#
# As mentioned in the earlier version of Cats Vs Dogs. The Image Augmentation part is added to the training data generator.
#
# 1. `horizontal_flip`: Flips the image Horizontally
# 2. `shear_range`:
# 3. `rotation_range`: Rotates the image by +/- of the value given it takes an input between 0 and 180
# 4. `width_shift_range`: Changes the width. Input is between 0 and 1
# 5. `height_shift_range: Changes the Height. Input is between 0 and 1
# 6. `fill_mode`: Decides the fill mode to fill blank pixels
# 7. `zoom_range`: Zooms the image. Input is between 0 and 1

# %%
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   shear_range=0.2,
                                   rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   fill_mode='nearest',
                                   zoom_range=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        train_dir,  # This is the source directory for training images
        target_size=(150, 150),  # All images will be resized to 150x150
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='binary')

# Flow validation images in batches of 20 using test_datagen generator
validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ### Fitting the Model
#
# Here we call the `fit` method. We pass the training generator as the first parameter and decide the number of epochs the model should be run on. The `validation_data` attribute takes in the validation generator.
#
# I will be running a 100 epochs so that I can plot the data

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=100,  # 2000 images = batch_size * steps
      epochs=100,
      validation_data=validation_generator,
      validation_steps=50,  # 1000 images = batch_size * steps
      verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.6963 - accuracy: 0.5180 - val_loss: 0.6873 - val_accuracy: 0.5000
# Epoch 2/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.6819 - accuracy: 0.5505 - val_loss: 0.6678 - val_accuracy: 0.5340
# Epoch 3/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6693 - accuracy: 0.5800 - val_loss: 0.6618 - val_accuracy: 0.5850
# Epoch 4/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6548 - accuracy: 0.6090 - val_loss: 0.6233 - val_accuracy: 0.6420
# Epoch 5/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6420 - accuracy: 0.6310 - val_loss: 0.6026 - val_accuracy: 0.6610
# Epoch 6/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6287 - accuracy: 0.6365 - val_loss: 0.6587 - val_accuracy: 0.5970
# Epoch 7/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6162 - accuracy: 0.6655 - val_loss: 0.5866 - val_accuracy: 0.6850
# Epoch 8/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.6058 - accuracy: 0.6685 - val_loss: 0.6149 - val_accuracy: 0.6420
# Epoch 9/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5953 - accuracy: 0.6765 - val_loss: 0.6175 - val_accuracy: 0.6590
# Epoch 10/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5844 - accuracy: 0.6810 - val_loss: 0.5534 - val_accuracy: 0.7210
# Epoch 11/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5913 - accuracy: 0.6890 - val_loss: 0.5486 - val_accuracy: 0.7130
# Epoch 12/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5732 - accuracy: 0.6915 - val_loss: 0.5720 - val_accuracy: 0.7000
# Epoch 13/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.5877 - accuracy: 0.6915 - val_loss: 0.5644 - val_accuracy: 0.7050
# Epoch 14/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5665 - accuracy: 0.7075 - val_loss: 0.5610 - val_accuracy: 0.6810
# Epoch 15/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5746 - accuracy: 0.6960 - val_loss: 0.5428 - val_accuracy: 0.7220
# Epoch 16/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5576 - accuracy: 0.7030 - val_loss: 0.5991 - val_accuracy: 0.6850
# Epoch 17/100
# 100/100 [==============================] - 18s 185ms/step - loss: 0.5528 - accuracy: 0.7090 - val_loss: 0.5390 - val_accuracy: 0.7160
# Epoch 18/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5488 - accuracy: 0.7185 - val_loss: 0.6502 - val_accuracy: 0.6570
# Epoch 19/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.5480 - accuracy: 0.7250 - val_loss: 0.5314 - val_accuracy: 0.7100
# Epoch 20/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.5471 - accuracy: 0.7165 - val_loss: 0.5313 - val_accuracy: 0.7290
# Epoch 21/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5361 - accuracy: 0.7290 - val_loss: 0.5033 - val_accuracy: 0.7430
# Epoch 22/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5286 - accuracy: 0.7280 - val_loss: 0.5014 - val_accuracy: 0.7340
# Epoch 23/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5422 - accuracy: 0.7320 - val_loss: 0.5593 - val_accuracy: 0.7020
# Epoch 24/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5256 - accuracy: 0.7305 - val_loss: 0.4999 - val_accuracy: 0.7440
# Epoch 25/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5268 - accuracy: 0.7335 - val_loss: 0.4878 - val_accuracy: 0.7620
# Epoch 26/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.5213 - accuracy: 0.7410 - val_loss: 0.4856 - val_accuracy: 0.7540
# Epoch 27/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5129 - accuracy: 0.7400 - val_loss: 0.4921 - val_accuracy: 0.7480
# Epoch 28/100
# 100/100 [==============================] - 18s 184ms/step - loss: 0.5097 - accuracy: 0.7410 - val_loss: 0.4717 - val_accuracy: 0.7720
# Epoch 29/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5069 - accuracy: 0.7495 - val_loss: 0.4833 - val_accuracy: 0.7610
# Epoch 30/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5100 - accuracy: 0.7530 - val_loss: 0.4722 - val_accuracy: 0.7740
# Epoch 31/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.5060 - accuracy: 0.7575 - val_loss: 0.4617 - val_accuracy: 0.7920
# Epoch 32/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.5043 - accuracy: 0.7490 - val_loss: 0.4831 - val_accuracy: 0.7650
# Epoch 33/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4934 - accuracy: 0.7605 - val_loss: 0.4825 - val_accuracy: 0.7620
# Epoch 34/100
# 100/100 [==============================] - 19s 185ms/step - loss: 0.4797 - accuracy: 0.7615 - val_loss: 0.4711 - val_accuracy: 0.7570
# Epoch 35/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4813 - accuracy: 0.7650 - val_loss: 0.4975 - val_accuracy: 0.7590
# Epoch 36/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4859 - accuracy: 0.7660 - val_loss: 0.4725 - val_accuracy: 0.7730
# Epoch 37/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4864 - accuracy: 0.7550 - val_loss: 0.4761 - val_accuracy: 0.7530
# Epoch 38/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4777 - accuracy: 0.7695 - val_loss: 0.4500 - val_accuracy: 0.7910
# Epoch 39/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4722 - accuracy: 0.7715 - val_loss: 0.4789 - val_accuracy: 0.7770
# Epoch 40/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4747 - accuracy: 0.7625 - val_loss: 0.4631 - val_accuracy: 0.7670
# Epoch 41/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4664 - accuracy: 0.7730 - val_loss: 0.4982 - val_accuracy: 0.7610
# Epoch 42/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4670 - accuracy: 0.7755 - val_loss: 0.4625 - val_accuracy: 0.7810
# Epoch 43/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4599 - accuracy: 0.7790 - val_loss: 0.4937 - val_accuracy: 0.7550
# Epoch 44/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4539 - accuracy: 0.7880 - val_loss: 0.4945 - val_accuracy: 0.7670
# Epoch 45/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4496 - accuracy: 0.7845 - val_loss: 0.4496 - val_accuracy: 0.7760
# Epoch 46/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4488 - accuracy: 0.7920 - val_loss: 0.5237 - val_accuracy: 0.7610
# Epoch 47/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4635 - accuracy: 0.7740 - val_loss: 0.4309 - val_accuracy: 0.7930
# Epoch 48/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4350 - accuracy: 0.7925 - val_loss: 0.4312 - val_accuracy: 0.7970
# Epoch 49/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4591 - accuracy: 0.7810 - val_loss: 0.4309 - val_accuracy: 0.8000
# Epoch 50/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.4564 - accuracy: 0.7820 - val_loss: 0.4343 - val_accuracy: 0.7920
# Epoch 51/100
# 100/100 [==============================] - 18s 185ms/step - loss: 0.4407 - accuracy: 0.7925 - val_loss: 0.5621 - val_accuracy: 0.7160
# Epoch 52/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4385 - accuracy: 0.7880 - val_loss: 0.4857 - val_accuracy: 0.7720
# Epoch 53/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4403 - accuracy: 0.7930 - val_loss: 0.5296 - val_accuracy: 0.7450
# Epoch 54/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4408 - accuracy: 0.7950 - val_loss: 0.5373 - val_accuracy: 0.7330
# Epoch 55/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.4439 - accuracy: 0.7785 - val_loss: 0.4521 - val_accuracy: 0.7770
# Epoch 56/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4252 - accuracy: 0.8065 - val_loss: 0.4524 - val_accuracy: 0.7980
# Epoch 57/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4355 - accuracy: 0.7920 - val_loss: 0.4257 - val_accuracy: 0.7980
# Epoch 58/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4305 - accuracy: 0.7945 - val_loss: 0.5430 - val_accuracy: 0.7160
# Epoch 59/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4357 - accuracy: 0.7950 - val_loss: 0.4839 - val_accuracy: 0.7520
# Epoch 60/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4204 - accuracy: 0.8110 - val_loss: 0.4668 - val_accuracy: 0.7840
# Epoch 61/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4197 - accuracy: 0.8030 - val_loss: 0.4620 - val_accuracy: 0.7870
# Epoch 62/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4231 - accuracy: 0.8075 - val_loss: 0.4325 - val_accuracy: 0.7960
# Epoch 63/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4336 - accuracy: 0.7910 - val_loss: 0.4572 - val_accuracy: 0.7710
# Epoch 64/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4043 - accuracy: 0.8160 - val_loss: 0.5244 - val_accuracy: 0.7350
# Epoch 65/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.4149 - accuracy: 0.8010 - val_loss: 0.5004 - val_accuracy: 0.7530
# Epoch 66/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4060 - accuracy: 0.8125 - val_loss: 0.4290 - val_accuracy: 0.7880
# Epoch 67/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4186 - accuracy: 0.7945 - val_loss: 0.4441 - val_accuracy: 0.7850
# Epoch 68/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.4220 - accuracy: 0.8015 - val_loss: 0.4021 - val_accuracy: 0.8160
# Epoch 69/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3964 - accuracy: 0.8255 - val_loss: 0.4532 - val_accuracy: 0.7880
# Epoch 70/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3950 - accuracy: 0.8200 - val_loss: 0.4157 - val_accuracy: 0.8030
# Epoch 71/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4010 - accuracy: 0.8075 - val_loss: 0.4520 - val_accuracy: 0.8050
# Epoch 72/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3988 - accuracy: 0.8150 - val_loss: 0.4240 - val_accuracy: 0.7950
# Epoch 73/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3994 - accuracy: 0.8170 - val_loss: 0.4945 - val_accuracy: 0.7520
# Epoch 74/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.4026 - accuracy: 0.8160 - val_loss: 0.4262 - val_accuracy: 0.7920
# Epoch 75/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3935 - accuracy: 0.8210 - val_loss: 0.3975 - val_accuracy: 0.8080
# Epoch 76/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3849 - accuracy: 0.8180 - val_loss: 0.3988 - val_accuracy: 0.8020
# Epoch 77/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3926 - accuracy: 0.8235 - val_loss: 0.4269 - val_accuracy: 0.7950
# Epoch 78/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3761 - accuracy: 0.8245 - val_loss: 0.4020 - val_accuracy: 0.8130
# Epoch 79/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3872 - accuracy: 0.8220 - val_loss: 0.4006 - val_accuracy: 0.8160
# Epoch 80/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3916 - accuracy: 0.8205 - val_loss: 0.3989 - val_accuracy: 0.8190
# Epoch 81/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3866 - accuracy: 0.8330 - val_loss: 0.4175 - val_accuracy: 0.8110
# Epoch 82/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3735 - accuracy: 0.8370 - val_loss: 0.4469 - val_accuracy: 0.7880
# Epoch 83/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3755 - accuracy: 0.8315 - val_loss: 0.4063 - val_accuracy: 0.7920
# Epoch 84/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3994 - accuracy: 0.8120 - val_loss: 0.4026 - val_accuracy: 0.8140
# Epoch 85/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3820 - accuracy: 0.8320 - val_loss: 0.4607 - val_accuracy: 0.7790
# Epoch 86/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3724 - accuracy: 0.8345 - val_loss: 0.3993 - val_accuracy: 0.8110
# Epoch 87/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3706 - accuracy: 0.8310 - val_loss: 0.4243 - val_accuracy: 0.8120
# Epoch 88/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3698 - accuracy: 0.8250 - val_loss: 0.4431 - val_accuracy: 0.7830
# Epoch 89/100
# 100/100 [==============================] - 18s 183ms/step - loss: 0.3807 - accuracy: 0.8295 - val_loss: 0.4084 - val_accuracy: 0.8130
# Epoch 90/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3698 - accuracy: 0.8325 - val_loss: 0.4164 - val_accuracy: 0.8140
# Epoch 91/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3644 - accuracy: 0.8335 - val_loss: 0.4325 - val_accuracy: 0.8070
# Epoch 92/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3496 - accuracy: 0.8385 - val_loss: 0.4584 - val_accuracy: 0.8050
# Epoch 93/100
# 100/100 [==============================] - 18s 182ms/step - loss: 0.3459 - accuracy: 0.8480 - val_loss: 0.3986 - val_accuracy: 0.8160
# Epoch 94/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3696 - accuracy: 0.8390 - val_loss: 0.4042 - val_accuracy: 0.8140
# Epoch 95/100
# 100/100 [==============================] - 18s 181ms/step - loss: 0.3500 - accuracy: 0.8475 - val_loss: 0.4937 - val_accuracy: 0.7930
# Epoch 96/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3636 - accuracy: 0.8365 - val_loss: 0.4037 - val_accuracy: 0.8090
# Epoch 97/100
# 100/100 [==============================] - 18s 180ms/step - loss: 0.3551 - accuracy: 0.8445 - val_loss: 0.4045 - val_accuracy: 0.8100
# Epoch 98/100
# 100/100 [==============================] - 18s 179ms/step - loss: 0.3486 - accuracy: 0.8450 - val_loss: 0.4665 - val_accuracy: 0.7970
# Epoch 99/100
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3599 - accuracy: 0.8360 - val_loss: 0.4130 - val_accuracy: 0.8160
# Epoch 100/100
# 100/100 [==============================] - 18s 179ms/step - loss: 0.3555 - accuracy: 0.8415 - val_loss: 0.4127 - val_accuracy: 0.8200

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# Accuracy and Loss plots for comparing the training accuracy and validation accuracy and training loss and validation loss

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# Here you can view how an image looks as it passes through all the convolution and pooling layers

# %%
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Let's prepare a random input image of a cat or dog from the training set.
cat_img_files = [os.path.join(train_cats_dir, f) for f in train_cat_fnames]
dog_img_files = [os.path.join(train_dogs_dir, f) for f in train_dog_fnames]

img_path = random.choice(cat_img_files + dog_img_files)
img = load_img(img_path, target_size=(150, 150))  # this is a PIL image

x   = img_to_array(img)                           # Numpy array with shape (150, 150, 3)
x   = x.reshape((1,) + x.shape)                   # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255.0

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]

# -----------------------------------------------------------------------
# Now let's display our representations
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Postprocess the feature to be visually palatable
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Tile each filter into a horizontal grid

    #-----------------
    # Display the grid
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * 2 *n_features, 2 * scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='viridis' )
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: RuntimeWarning: invalid value encountered in true_divide
